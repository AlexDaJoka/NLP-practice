# %% [markdown]
# Embedding

# %%
import pandas as pd

df = pd.read_excel("/content/Clean_text_30001.xlsx")

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import pandas as pd

# --- Load model ---
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

df['review'] = df['review'].fillna("").astype(str)
df = df[df['review'].str.strip().str.len() > 5]

# --- Generate embeddings ---
def generate_embeddings(texts, batch_size=64, normalize=True):
    embeddings = []
    for i in tqdm(range(0, len(texts), batch_size)):
        batch = texts[i:i + batch_size]
        emb = model.encode(
            batch,
            show_progress_bar=False,
            normalize_embeddings=normalize
        )
        embeddings.append(emb)
    return np.vstack(embeddings)

df['embeddings'] = list(generate_embeddings(df['review'].tolist()))
# Out:
#   4%|▍         | 17/449 [01:40<42:29,  5.90s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2733090257.py in <cell line: 0>()
#      23     return np.vstack(embeddings)
#      24
# ---> 25 df['embeddings'] = list(generate_embeddings(df['review'].tolist()))
#
# /tmp/ipython-input-2733090257.py in generate_embeddings(texts, batch_size, normalize)
#      15     for i in tqdm(range(0, len(texts), batch_size)):
#      16         batch = texts[i:i + batch_size]
# ---> 17         emb = model.encode(
#      18             batch,
#      19             show_progress_bar=False,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
# ...

# %%
#df2 = pd.read_excel("/content/vectorized_ready_text.xlsx")

#df2

df["embeddings"] = df2["review"]

df.to_excel("vectorized_ready_text.xlsx", index=False)

# %%
#df.to_excel("vectorized_ready_text.xlsx", index=False)

df.to_parquet(
    "vectorized_ready_text.parquet",
    engine="pyarrow",
    index=False
)
