# %% [markdown]
# Генерация embeddings + feature matrix

# %%
import pandas as pd

df = pd.read_excel("/content/Ready_clean_sample.xlsx")

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# --- Load model ---
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

def generate_embeddings(
    texts,
    batch_size=64,
    normalize=True
):
    embeddings = []

    for i in tqdm(range(0, len(texts), batch_size)):
        batch = texts[i:i + batch_size]
        emb = model.encode(
            batch,
            show_progress_bar=False,
            normalize_embeddings=normalize
        )
        embeddings.append(emb)

    return np.vstack(embeddings)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
texts = df["text"].fillna("").tolist()

X_emb = generate_embeddings(texts, batch_size=64)

print(X_emb.shape)
# (30000, 384)
# Out:
# 100%|██████████| 469/469 [10:27<00:00,  1.34s/it]
# (30001, 384)

# %%
tabular_features = [
    "text_length",
    "word_count",
    "num_exclamations",
    "has_urgent"
]

X_tab = df[tabular_features].values

# %%
from numpy import hstack

X = hstack([X_emb, X_tab])

# %%
X.shape = (len(df), 384 + len(tabular_features))

print(X.shape)
# Out:
# (30001, 388)

# %% [markdown]
# Target

# %%
label_map = {
    "low": 0,
    "medium": 1,
    "high": 2,
    "critical": 3
}

y = df["priority_score"].map(label_map).values

# %% [markdown]
# Train/val/split

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %% [markdown]
# Проверка на sanity-check

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity(X_emb[:5])
# Out:
# array([[1.0000001 , 0.48126093, 0.40945172, 0.71243304, 0.39938685],
#        [0.48126093, 1.0000001 , 0.28587198, 0.42005306, 0.5955684 ],
#        [0.40945172, 0.28587198, 0.9999999 , 0.525432  , 0.30601195],
#        [0.71243304, 0.42005306, 0.525432  , 0.99999994, 0.40559393],
#        [0.39938685, 0.5955684 , 0.30601195, 0.40559393, 1.        ]],
#       dtype=float32)

# %% [markdown]
# Обучаем XGBoost

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (24000, 388) (6001, 388)
# (24000,) (6001,)

# %% [markdown]
# Работа с дисбалансом классов

# %%
import numpy as np

classes, counts = np.unique(y_train, return_counts=True)
print(dict(zip(classes, counts)))
# Out:
# {np.int64(1): np.int64(1114), np.int64(2): np.int64(22369), np.int64(3): np.int64(517)}

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train),
    y=y_train
)

class_weight_map = dict(zip(np.unique(y_train), class_weights))

sample_weights = np.array([class_weight_map[y] for y in y_train])

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(X_train, label=y_train, weight=sample_weights)
dval = xgb.DMatrix(X_val, label=y_val)

params = {
    "objective": "multi:softprob",
    "num_class": 4,
    "max_depth": 6,
    "eta": 0.05,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "eval_metric": "mlogloss",
}

model = xgb.train(
    params,
    dtrain,
    num_boost_round=500,
    evals=[(dval, "val")],
    early_stopping_rounds=30
)
# Out:
# [0]	val-mlogloss:1.27659
# [1]	val-mlogloss:1.24295
# [2]	val-mlogloss:1.21210
# [3]	val-mlogloss:1.18061
# [4]	val-mlogloss:1.15033
# [5]	val-mlogloss:1.12336
# [6]	val-mlogloss:1.09778
# [7]	val-mlogloss:1.07187
# [8]	val-mlogloss:1.04954
# [9]	val-mlogloss:1.02678
# [10]	val-mlogloss:1.00458
# [11]	val-mlogloss:0.98418
# [12]	val-mlogloss:0.96435
# [13]	val-mlogloss:0.94621
# [14]	val-mlogloss:0.92689
# [15]	val-mlogloss:0.90827
# [16]	val-mlogloss:0.89169
# [17]	val-mlogloss:0.87423
# [18]	val-mlogloss:0.85773
# [19]	val-mlogloss:0.84171
# [20]	val-mlogloss:0.82842
# [21]	val-mlogloss:0.81286
# [22]	val-mlogloss:0.79869
# [23]	val-mlogloss:0.78460
# [24]	val-mlogloss:0.77131
# [25]	val-mlogloss:0.75975
# [26]	val-mlogloss:0.74830
# [27]	val-mlogloss:0.73599
# [28]	val-mlogloss:0.72370
# [29]	val-mlogloss:0.71201
# [30]	val-mlogloss:0.70121
# [31]	val-mlogloss:0.69119
# [32]	val-mlogloss:0.68016
# [33]	val-mlogloss:0.66991
# [34]	val-mlogloss:0.66076
# [35]	val-mlogloss:0.65117
# [36]	val-mlogloss:0.64183
# [37]	val-mlogloss:0.63242
# [38]	val-mlogloss:0.62414
# [39]	val-mlogloss:0.61568
# [40]	val-mlogloss:0.60687
# [41]	val-mlogloss:0.59918
# [42]	val-mlogloss:0.59038
# [43]	val-mlogloss:0.58231
# [44]	val-mlogloss:0.57411
# [45]	val-mlogloss:0.56597
# [46]	val-mlogloss:0.55872
# [47]	val-mlogloss:0.55182
# [48]	val-mlogloss:0.54534
# [49]	val-mlogloss:0.53875
# [50]	val-mlogloss:0.53125
# [51]	val-mlogloss:0.52441
# [52]	val-mlogloss:0.51785
# [53]	val-mlogloss:0.51111
# [54]	val-mlogloss:0.50597
# [55]	val-mlogloss:0.49948
# [56]	val-mlogloss:0.49407
# [57]	val-mlogloss:0.48855
# [58]	val-mlogloss:0.48264
# [59]	val-mlogloss:0.47690
# [60]	val-mlogloss:0.47219
# [61]	val-mlogloss:0.46713
# [62]	val-mlogloss:0.46190
# [63]	val-mlogloss:0.45600
# [64]	val-mlogloss:0.45067
# [65]	val-mlogloss:0.44572
# [66]	val-mlogloss:0.44197
# [67]	val-mlogloss:0.43770
# [68]	val-mlogloss:0.43237
# [69]	val-mlogloss:0.42746
# [70]	val-mlogloss:0.42283
# [71]	val-mlogloss:0.41847
# [72]	val-mlogloss:0.41444
# [73]	val-mlogloss:0.41020
# [74]	val-mlogloss:0.40563
# [75]	val-mlogloss:0.40179
# [76]	val-mlogloss:0.39737
# [77]	val-mlogloss:0.39319
# [78]	val-mlogloss:0.38922
# [79]	val-mlogloss:0.38480
# [80]	val-mlogloss:0.38112
# [81]	val-mlogloss:0.37765
# [82]	val-mlogloss:0.37421
# [83]	val-mlogloss:0.37023
# [84]	val-mlogloss:0.36702
# [85]	val-mlogloss:0.36328
# [86]	val-mlogloss:0.35953
# [87]	val-mlogloss:0.35648
# [88]	val-mlogloss:0.35297
# [89]	val-mlogloss:0.34966
# [90]	val-mlogloss:0.34644
# [91]	val-mlogloss:0.34380
# [92]	val-mlogloss:0.34026
# [93]	val-mlogloss:0.33698
# [94]	val-mlogloss:0.33410
# [95]	val-mlogloss:0.33146
# [96]	val-mlogloss:0.32832
# [97]	val-mlogloss:0.32546
# [182]	val-mlogloss:0.19437
# [183]	val-mlogloss:0.19336
# [184]	val-mlogloss:0.19271
# [185]	val-mlogloss:0.19204
# [186]	val-mlogloss:0.19124
# [187]	val-mlogloss:0.19052
# [188]	val-mlogloss:0.18953
# [189]	val-mlogloss:0.18889
# [190]	val-mlogloss:0.18812
# [191]	val-mlogloss:0.18748
# [192]	val-mlogloss:0.18681
# [193]	val-mlogloss:0.18600
# [194]	val-mlogloss:0.18532
# [195]	val-mlogloss:0.18464
# [196]	val-mlogloss:0.18418
# [197]	val-mlogloss:0.18349
# [198]	val-mlogloss:0.18283
# [199]	val-mlogloss:0.18222
# [200]	val-mlogloss:0.18155
# [201]	val-mlogloss:0.18083
# [202]	val-mlogloss:0.18031
# [203]	val-mlogloss:0.17972
# [204]	val-mlogloss:0.17911
# [205]	val-mlogloss:0.17825
# [206]	val-mlogloss:0.17780
# [207]	val-mlogloss:0.17718
# [208]	val-mlogloss:0.17666
# [209]	val-mlogloss:0.17614
# [210]	val-mlogloss:0.17552
# [211]	val-mlogloss:0.17493
# [212]	val-mlogloss:0.17440
# [213]	val-mlogloss:0.17381
# [214]	val-mlogloss:0.17318
# [215]	val-mlogloss:0.17279
# [216]	val-mlogloss:0.17217
# [217]	val-mlogloss:0.17176
# [218]	val-mlogloss:0.17129
# [219]	val-mlogloss:0.17069
# [220]	val-mlogloss:0.17027
# [221]	val-mlogloss:0.16973
# [222]	val-mlogloss:0.16918
# [223]	val-mlogloss:0.16875
# [224]	val-mlogloss:0.16836
# [225]	val-mlogloss:0.16806
# [226]	val-mlogloss:0.16758
# [227]	val-mlogloss:0.16699
# [228]	val-mlogloss:0.16659
# [229]	val-mlogloss:0.16598
# [230]	val-mlogloss:0.16562
# [231]	val-mlogloss:0.16527
# [232]	val-mlogloss:0.16477
# [233]	val-mlogloss:0.16430
# [234]	val-mlogloss:0.16373
# [235]	val-mlogloss:0.16338
# [236]	val-mlogloss:0.16306
# [237]	val-mlogloss:0.16258
# [238]	val-mlogloss:0.16214
# [239]	val-mlogloss:0.16168
# [240]	val-mlogloss:0.16130
# [241]	val-mlogloss:0.16083
# [242]	val-mlogloss:0.16043
# [243]	val-mlogloss:0.16019
# [244]	val-mlogloss:0.15967
# [245]	val-mlogloss:0.15936
# [246]	val-mlogloss:0.15893
# [247]	val-mlogloss:0.15864
# [248]	val-mlogloss:0.15831
# [249]	val-mlogloss:0.15803
# [250]	val-mlogloss:0.15770
# [251]	val-mlogloss:0.15738
# [252]	val-mlogloss:0.15705
# [253]	val-mlogloss:0.15672
# [254]	val-mlogloss:0.15649
# [255]	val-mlogloss:0.15612
# [256]	val-mlogloss:0.15576
# [257]	val-mlogloss:0.15541
# [258]	val-mlogloss:0.15510
# [259]	val-mlogloss:0.15464
# [260]	val-mlogloss:0.15432
# [261]	val-mlogloss:0.15388
# [262]	val-mlogloss:0.15347
# [263]	val-mlogloss:0.15314
# [264]	val-mlogloss:0.15290
# [265]	val-mlogloss:0.15262
# [266]	val-mlogloss:0.15225
# [435]	val-mlogloss:0.13231
# [436]	val-mlogloss:0.13230
# [437]	val-mlogloss:0.13227
# [438]	val-mlogloss:0.13229
# [439]	val-mlogloss:0.13228
# [440]	val-mlogloss:0.13234
# [441]	val-mlogloss:0.13234
# [442]	val-mlogloss:0.13230
# [443]	val-mlogloss:0.13234
# [444]	val-mlogloss:0.13234
# [445]	val-mlogloss:0.13229
# [446]	val-mlogloss:0.13232
# [447]	val-mlogloss:0.13233
# [448]	val-mlogloss:0.13231
# [449]	val-mlogloss:0.13230
# [450]	val-mlogloss:0.13231
# [451]	val-mlogloss:0.13231
# [452]	val-mlogloss:0.13227
# [453]	val-mlogloss:0.13227
# [454]	val-mlogloss:0.13222
# [455]	val-mlogloss:0.13221
# [456]	val-mlogloss:0.13223
# [457]	val-mlogloss:0.13221
# [458]	val-mlogloss:0.13218
# [459]	val-mlogloss:0.13216
# [460]	val-mlogloss:0.13217
# [461]	val-mlogloss:0.13222
# [462]	val-mlogloss:0.13219
# [463]	val-mlogloss:0.13220
# [464]	val-mlogloss:0.13221
# [465]	val-mlogloss:0.13221
# [466]	val-mlogloss:0.13226
# [467]	val-mlogloss:0.13221
# [468]	val-mlogloss:0.13224
# [469]	val-mlogloss:0.13217
# [470]	val-mlogloss:0.13223
# [471]	val-mlogloss:0.13226
# [472]	val-mlogloss:0.13226
# [473]	val-mlogloss:0.13230
# [474]	val-mlogloss:0.13235
# [475]	val-mlogloss:0.13232
# [476]	val-mlogloss:0.13233
# [477]	val-mlogloss:0.13231
# [478]	val-mlogloss:0.13238
# [479]	val-mlogloss:0.13241
# [480]	val-mlogloss:0.13240
# [481]	val-mlogloss:0.13237
# [482]	val-mlogloss:0.13238
# [483]	val-mlogloss:0.13233
# [484]	val-mlogloss:0.13238
# [485]	val-mlogloss:0.13244
# [486]	val-mlogloss:0.13255
# [487]	val-mlogloss:0.13259
# [488]	val-mlogloss:0.13252
# [489]	val-mlogloss:0.13255

# %% [markdown]
# Предсказание

# %%
# X_val уже есть, создаём DMatrix
dval = xgb.DMatrix(X_val)

# Получаем вероятности
y_proba = model.predict(dval)  # shape: (n_samples, num_class)

# Получаем метки (argmax)
y_pred = y_proba.argmax(axis=1)
# Out:
# <xgboost.core.DMatrix object at 0x7d265e0bd3d0>

# %% [markdown]
# Метрики

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Классы в порядке 0:low,1:medium,2:high,3:critical
print(classification_report(y_val, y_pred, target_names=["medium","high","critical"]))

print("Confusion Matrix:")
print(confusion_matrix(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       medium       0.81      0.43      0.56       279
#         high       0.96      0.99      0.98      5593
#     critical       0.90      0.57      0.70       129
#
#     accuracy                           0.96      6001
#    macro avg       0.89      0.66      0.75      6001
# weighted avg       0.95      0.96      0.95      6001
#
# Confusion Matrix:
# [[ 119  160    0]
#  [  27 5558    8]
#  [   1   54   74]]

# %% [markdown]
# Бизнес метрики

# %%
from sklearn.metrics import recall_score

critical_label = 3  # индекс класса critical

recall_critical = recall_score(y_val, y_pred, labels=[critical_label], average="macro")
print("Recall (critical):", recall_critical)
# Out:
# Recall (critical): 0.5736434108527132
