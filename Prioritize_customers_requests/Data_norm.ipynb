# %% [markdown]
# EDA

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/30000_sample.csv')

# %%
df.to_excel('/content/30000_sample.xlsx', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 30001 non-null  int64
#  1   author_id                30001 non-null  object
#  2   inbound                  30001 non-null  bool
#  3   created_at               30001 non-null  object
#  4   text                     30001 non-null  object
#  5   response_tweet_id        20223 non-null  object
#  6   in_response_to_tweet_id  22399 non-null  float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#            tweet_id  in_response_to_tweet_id
# count  30001.000000             22399.000000
# mean   19555.911336             19635.366802
# std    10807.851698             10786.129366
# min        1.000000                 1.000000
# 25%    10964.000000             11036.500000
# 50%    19338.000000             19815.000000
# 75%    28840.000000             28868.500000
# max    38481.000000             38482.000000

# %%
df.isnull().sum()
# Out:
# tweet_id                      0
# author_id                     0
# inbound                       0
# created_at                    0
# text                          0
# response_tweet_id          9778
# in_response_to_tweet_id    7602
# dtype: int64

# %%
df = df.drop(columns=['tweet_id', 'author_id', 'response_tweet_id', 'in_response_to_tweet_id'])

df
# Out:
#        inbound                      created_at  \
# 0        False  Tue Oct 31 22:10:47 +0000 2017
# 1         True  Tue Oct 31 22:11:45 +0000 2017
# 2         True  Tue Oct 31 22:08:27 +0000 2017
# 3        False  Tue Oct 31 21:54:49 +0000 2017
# 4         True  Tue Oct 31 21:49:35 +0000 2017
# ...        ...                             ...
# 29996    False  Mon Nov 06 21:01:22 +0000 2017
# 29997     True  Tue Oct 31 10:21:16 +0000 2017
# 29998    False  Tue Oct 31 10:05:54 +0000 2017
# 29999     True  Mon Oct 30 20:45:15 +0000 2017
# 30000    False  Wed Nov 01 14:32:09 +0000 2017
#
#                                                     text
# 0      @115712 I understand. I would like to assist y...
# 1          @sprintcare and how do you propose we do that
# 2      @sprintcare I have sent several private messag...
# 3      @115712 Please send us a Private Message so th...
# 4                                     @sprintcare I did.
# ...
